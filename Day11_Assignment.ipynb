# %%
# Day 11 — Numpy & Pandas (BMI Calculation + Data Cleaning)

# --------------------------------------------------------------
# ✅ Task 1: There are 5 students with height & weight. Calculate BMI.
# --------------------------------------------------------------

import pandas as pd

# Sample student data
data = {
    'Name': ['A', 'B', 'C', 'D', 'E'],
    'Height_cm': [160, 170, 165, 155, 180],  # height in centimeters
    'Weight_kg': [55, 65, 70, 50, 80]        # weight in kilograms
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert height from cm to meters
df['Height_m'] = df['Height_cm'] / 100

# BMI Formula = Weight (kg) / (Height (m) ^ 2)
df['BMI'] = df['Weight_kg'] / (df['Height_m'] ** 2)

print("✅ BMI Calculation Result:")
print(df)
# Out:
# ✅ BMI Calculation Result:
#   Name  Height_cm  Weight_kg  Height_m        BMI
# 0    A        160         55      1.60  21.484375
# 1    B        170         65      1.70  22.491349
# 2    C        165         70      1.65  25.711662
# 3    D        155         50      1.55  20.811655
# 4    E        180         80      1.80  24.691358

# %%
# --------------------------------------------------------------
# ✅ Task 2: Demonstrate Data Cleaning Methods in Pandas
# --------------------------------------------------------------

import pandas as pd
import numpy as np

# Sample dataset with missing values, wrong data, duplicates
clean_df = pd.DataFrame({
    'Date': ['2025-10-01', None, '2025-10-03', '2025-10-04'],
    'Calories': [420, None, 300, 300],
    'Duration': [45, 450, 30, 450]
})

print("🔹 Original Data:")
display(clean_df)

# 1) Drop Null Values
print("\n1️⃣ Drop Null Rows (dropna):")
display(clean_df.dropna())

# 2) Replace Empty Values
print("\n2️⃣ Replace All Empty with 130 (fillna):")
temp = clean_df.copy()
temp.fillna(130, inplace=True)
display(temp)

# 3) Replace Only Specific Column
print("\n3️⃣ Replace Only 'Calories' Null with 130:")
temp = clean_df.copy()
temp['Calories'].fillna(130, inplace=True)
display(temp)

# 4) Replace Using Mean
print("\n4️⃣ Replace Using Mean of 'Calories':")
temp = clean_df.copy()
temp['Calories'].fillna(temp['Calories'].mean(), inplace=True)
display(temp)

# 5) Drop rows with wrong Date format
print("\n5️⃣ Drop rows where Date is Null:")
temp = clean_df.copy()
temp = temp.dropna(subset=['Date'])
display(temp)

# 6) Convert to Correct Date Format
print("\n6️⃣ Convert 'Date' to Datetime Format:")
temp = clean_df.copy()
temp['Date'] = pd.to_datetime(temp['Date'], errors='coerce')
display(temp)

# 7) Replace Wrong Data (Duration > 120)
print("\n7️⃣ Replace Duration > 120 with 120:")
temp = clean_df.copy()
temp.loc[temp['Duration'] > 120, 'Duration'] = 120
display(temp)

# 8) Drop Wrong Data (Duration > 120)
print("\n8️⃣ Drop Rows Where Duration > 120:")
temp = clean_df.copy()
temp = temp[temp['Duration'] <= 120]
display(temp)

# 9) Check Duplicates
print("\n9️⃣ Check for Duplicates:")
print(clean_df.duplicated())

# 10) Remove Duplicates
print("\n🔟 Remove Duplicates:")
display(clean_df.drop_duplicates())
# Out:
# 🔹 Original Data:
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 1        None       NaN       450
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
# 1️⃣ Drop Null Rows (dropna):
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
# 2️⃣ Replace All Empty with 130 (fillna):
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 1         130     130.0       450
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
# 3️⃣ Replace Only 'Calories' Null with 130:
# C:\Users\veer2\AppData\Local\Temp\ipykernel_14516\2477982048.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   temp['Calories'].fillna(130, inplace=True)
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 1        None     130.0       450
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
# 4️⃣ Replace Using Mean of 'Calories':
# C:\Users\veer2\AppData\Local\Temp\ipykernel_14516\2477982048.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   temp['Calories'].fillna(temp['Calories'].mean(), inplace=True)
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 1        None     340.0       450
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
# 5️⃣ Drop rows where Date is Null:
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
# 6️⃣ Convert 'Date' to Datetime Format:
#         Date  Calories  Duration
# 0 2025-10-01     420.0        45
# 1        NaT       NaN       450
# 2 2025-10-03     300.0        30
# 3 2025-10-04     300.0       450
# 7️⃣ Replace Duration > 120 with 120:
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 1        None       NaN       120
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       120
# 8️⃣ Drop Rows Where Duration > 120:
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 2  2025-10-03     300.0        30
# 9️⃣ Check for Duplicates:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
#
# 🔟 Remove Duplicates:
#          Date  Calories  Duration
# 0  2025-10-01     420.0        45
# 1        None       NaN       450
# 2  2025-10-03     300.0        30
# 3  2025-10-04     300.0       450
